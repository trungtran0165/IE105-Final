# %%
import pandas as pd

# %%
DT_log = pd.read_feather("DT_attackgan_log.feather")

# %%
DT_log
# Out:
#         step  epoch  loss_discriminator  loss_gen  loss_blackbox
# 0        0.0    1.0           -0.000001  7.555361      15.110714
# 1        1.0    1.0           -0.000004  7.933116      15.866250
# 2        2.0    1.0           -0.000006  7.933117      15.866250
# 3        3.0    1.0           -0.000009  7.933105      15.866250
# 4        4.0    1.0           -0.000012  7.555329      15.110714
# ...      ...    ...                 ...       ...            ...
# 10075  283.0   35.0           -0.000155  7.807158      15.614405
# 10076  284.0   35.0           -0.000195  7.807132      15.614405
# 10077  285.0   35.0           -0.000166  7.807156      15.614405
# 10078  286.0   35.0           -0.000133  7.555303      15.110714
# 10079  287.0   35.0           -0.000341  8.058869      16.118095
#
# [10080 rows x 5 columns]
