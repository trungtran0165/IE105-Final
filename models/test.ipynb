# %%
import pickle
from sklearn.tree import DecisionTreeClassifier

# %%
clf_dt = DecisionTreeClassifier(criterion="entropy", min_samples_leaf=1000)

# %%
import pandas as pd
X = pd.read_csv('../dataset/train_classifier.csv')
y = X.iloc[:, -1]
X = X.iloc[:, :-1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 X = pd.read_csv('../dataset/train_classifier.csv')
#       3 y = X.iloc[:, -1]
#       4 X = X.iloc[:, :-1]
#
# ...

# %%
clf_dt.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=1000)

# %%
clf_dt.predict_proba(X.sample(13))
# Out:
# array([[0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [5.67319461e-01, 4.00856793e-01, 3.12117503e-02, 0.00000000e+00,
#         6.11995104e-04],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [9.89769821e-01, 1.70502984e-03, 6.82011935e-03, 0.00000000e+00,
#         1.70502984e-03],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [4.00000000e-02, 1.00000000e-03, 9.59000000e-01, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...
